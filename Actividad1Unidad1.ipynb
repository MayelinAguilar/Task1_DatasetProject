# %%
import pandas as pd

df = pd.read_csv("DNP-ProductoSector.csv")

#Percentil 
df.describe()
# Out:
#            Cantidad  MetaIndicador  AvanceIndicador  ValorProducto
# count  3.720310e+05   3.720310e+05     3.720310e+05   3.718230e+05
# mean   9.568506e+07   9.506583e+07     6.696138e+07   4.842862e+09
# std    2.535762e+10   2.541023e+10     2.478682e+10   1.385807e+11
# min    0.000000e+00   0.000000e+00     0.000000e+00   0.000000e+00
# 25%    1.000000e+00   1.000000e+00     0.000000e+00   4.800000e+06
# 50%    7.000000e+00   8.000000e+00     0.000000e+00   5.756527e+07
# 75%    1.690000e+02   2.000000e+02     1.000000e+00   3.729010e+08
# max    1.422167e+13   1.422167e+13     1.422167e+13   3.349194e+13

# %%
import pandas as pd

df = pd.read_csv("DNP-ProductoSector.csv")

#Identificando columnnas 
df.columns
# Out:
# Index(['Sector', 'UnidadMedidaProducto', 'Indicador', 'UnidadMedidaIndicador',
#        'Producto', 'Cantidad', 'MetaIndicador', 'AvanceIndicador',
#        'ValorProducto'],
#       dtype='object')

# %%
# Out:
#                                    Sector  \
# 370031          Salud Y Protección Social
# 370032                         Transporte
# 370033               Deporte Y Recreación
# 370034                            Cultura
# 370035                         Transporte
# ...                                   ...
# 372026  Inclusión Social Y Reconciliación
# 372027       Comercio Industria Y Turismo
# 372028               Deporte Y Recreación
# 372029                          Educación
# 372030  Inclusión Social Y Reconciliación
#
#                                   UnidadMedidaProducto  \
# 370031                              Número de personas
# 370032                      Kilómetros de vías urbanas
# 370033                              Número de personas
# 370034                              Número de personas
# 370035                 Metros lineales de vías urbanas
# ...                                                ...
# 372026                               Número de centros
# ...

# %%
import pandas as pd

df = pd.read_csv("DNP-ProductoSector.csv")

#Guardando datos 
df.to_csv ('Select_DataSet.csv', sep=',',index=False)
